# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_wine 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
wine = load_wine()

# %%
print(wine.DESCR)
# Out:
# .. _wine_dataset:
#
# Wine recognition dataset
# ------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 178 (50 in each of three classes)
#     :Number of Attributes: 13 numeric, predictive attributes and the class
#     :Attribute Information:
#  		- Alcohol
#  		- Malic acid
#  		- Ash
# 		- Alcalinity of ash
#  		- Magnesium
# 		- Total phenols
#  		- Flavanoids
#  		- Nonflavanoid phenols
#  		- Proanthocyanins
# 		- Color intensity
#  		- Hue
#  		- OD280/OD315 of diluted wines
#  		- Proline
#
#     - class:
#             - class_0
#             - class_1
#             - class_2
#
#     :Summary Statistics:
#
#     ============================= ==== ===== ======= =====
#                                    Min   Max   Mean     SD
#     ============================= ==== ===== ======= =====
#     Alcohol:                      11.0  14.8    13.0   0.8
#     Malic Acid:                   0.74  5.80    2.34  1.12
# ...

# %%
features = pd.DataFrame(wine.data, columns=wine.feature_names)
target = pd.DataFrame(wine.target, columns=["TARGET"])

# %%
data = pd.concat([features,target], axis=1)

# %%
data
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# 5      14.20        1.76  2.45               15.2      112.0           3.27
# 6      14.39        1.87  2.45               14.6       96.0           2.50
# 7      14.06        2.15  2.61               17.6      121.0           2.60
# 8      14.83        1.64  2.17               14.0       97.0           2.80
# 9      13.86        1.35  2.27               16.0       98.0           2.98
# 10     14.10        2.16  2.30               18.0      105.0           2.95
# ...

# %%
data = data[data.TARGET != 2]

# %%
correlation = data.corr('pearson')
correlation["TARGET"].sort_values()
# Out:
# proline                        -0.845296
# alcohol                        -0.824399
# color_intensity                -0.750613
# flavanoids                     -0.610730
# total_phenols                  -0.532692
# od280/od315_of_diluted_wines   -0.391746
# magnesium                      -0.383085
# ash                            -0.354548
# proanthocyanins                -0.249205
# malic_acid                     -0.044302
# hue                            -0.017043
# nonflavanoid_phenols            0.337489
# alcalinity_of_ash               0.470437
# TARGET                          1.000000
# Name: TARGET, dtype: float64

# %%
X1 = data["proline"]
X2 = data["alcohol"]
Y = data["TARGET"]

# %%
plt.plot(X1,Y,"r.",
        X2,y,"b.")

# %%
X1 =(X1-X1.min())/(X1.max()-X1.min())
X2 =(X2-X2.min())/(X2.max()-X2.min())

# %%
x1 =np.array(X1)
x2 = np.array(X2)
y = np.array(Y)

# %%
plt.plot(X1,Y,"r.",
        X2,Y,"b.")

# %%
x1_train,x1_test,x2_train,x2_test,y_train,y_test = train_test_split(x1,x2,y,test_size = 0.2)

# %%
def hypothesis(a,x1,b,x2,c):
    return (1/(1+np.exp(-(a*x1 +b*x2+c))))

# %%
def error(a,x1,b,x2,c,y):
    e = 0
    m = len(x1)
    for i in range(m):
        e += (-y[i]*np.log(hypothesis(a,x1[i],b,x2[i],c))) - ((1 - y[i])*np.log(1 - hypothesis(a,x1[i],b,x2[i],c)))
    return (1/m)*e

# %%
def step_gradient(a,x1,b,x2,c,y,learning_rate):
    grad_a = 0
    grad_b = 0
    grad_c = 0
    m = len(x1)
    for i in range(m):
        grad_a += (hypothesis(a,x1[i],b,x2[i],c) - y[i]) * x1[i]
        grad_b += (hypothesis(a,x1[i],b,x2[i],c) - y[i]) * x2[i]
        grad_c += (hypothesis(a,x1[i],b,x2[i],c) - y[i]) 
    
    a = a - (grad_a * learning_rate)
    b = b - (grad_b * learning_rate)
    c = c - (grad_c * learning_rate)
    
    return a, b ,c

# %%
def descend(init_a,x1,init_b,x2,init_c,y,learning_rate,iterations):
    a = init_a
    b = init_b
    c = init_c
    for i in range(iterations):
        e = error(a, x1, b ,x2,c,y)
        if i % 1000 == 0:
            print(f"Error: {e}, a: {a}, b: {b}, c: {c}")
        
        a, b, c = step_gradient(a, x1,b,x2,c, y, learning_rate)

    return a, b ,c

# %%
init_a = 1
init_b = 1
init_c = 1
iterations = 10000
learning_rate = 0.01
final_a,final_b,final_c = descend(init_a,x1_train,init_b,x2_train,init_c,y_train,learning_rate,iterations)
# Out:
# Error: 1.1180429608836056, a: 1, b: 1, c: 1
# Error: 0.14040991451404855, a: -8.844007498543792, b: -8.8440074985438, c: 6.567055781087348
# Error: 0.13531660302898532, a: -10.254487023581483, b: -10.254487023581497, c: 7.566408809914512
# Error: 0.13421721191114433, a: -10.919415716739259, b: -10.91941571673928, c: 8.036861688727994
# Error: 0.13388753041401094, a: -11.285134601557873, b: -11.285134601557901, c: 8.295481335956497
# Error: 0.13377451035118257, a: -11.499675677815876, b: -11.499675677815912, c: 8.447156211314105
# Error: 0.13373304003656888, a: -11.629761713694387, b: -11.629761713694423, c: 8.539110718713943
# Error: 0.13371723307008837, a: -11.71011939144607, b: -11.710119391446106, c: 8.595908880897529
# Error: 0.13371107133397309, a: -11.760307030840584, b: -11.76030703084062, c: 8.631380606902818
# Error: 0.13370863648379866, a: -11.79186198490478, b: -11.791861984904816, c: 8.65368240978658

# %%
error(final_a,x1_train,final_b,x2_train,final_c,y_train)
# Out:
# 0.13370766620778216

# %%
error(final_a,x1_test,final_b,x2_test,final_c,y_test)
# Out:
# 0.2648026138788937

# %%
plt.plot(x_train,y_train,"r.",
        x_train,hypothesis(final_a,x1_train,final_b,x2_train,final_c,y_train),"b.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-faafe1e0e3e6> in <module>
#       1 plt.plot(x1_train,y_train,"r.",
# ----> 2         x1_train,hypothesis(final_a,x1_train,final_b,x2_train,final_c,y_train),"b.")
#
# TypeError: hypothesis() takes 5 positional arguments but 6 were given

# %%
def accuracy(a,x1,b,x2,y):
    correct = 0
    m = len(x1)
    for i in range(m):
        pred = hypothesis(a,x1[i],b,x2,c)
        
        if pred > 0.5:
            z = 1
        else:
            z = 0
        if y[i] == z:
            correct += 1
    print(f"Accuracy:{correct/len(y)}")

# %%
accuracy(final_a,x1_test,final_b,y_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-7ea6f13ca8ce> in <module>
# ----> 1 accuracy(final_a,x_test,final_b,y_test)
#
# <ipython-input-73-a951bad0b71b> in accuracy(a, x, b, y)
#       3     m = len(x)
#       4     for i in range(m):
# ----> 5         pred = hypothesis(a,x[i],b)
#       6
#       7         if pred > 0.5:
#
# TypeError: hypothesis() missing 2 required positional arguments: 'x2' and 'c'
